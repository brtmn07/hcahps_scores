# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Bringing in all the years csv data. not cleaned.

# %%
hcahps_2017 = pd.read_csv('../data/hcahps_2018.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\271575273.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2017 = pd.read_csv('../data/hcahps_2018.csv')

# %%
hcahps_2017.head(1)
# Out:
#   Provider ID                     Hospital Name                 Address  \
# 0       10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701     H_STAR_RATING
#
#        HCAHPS Question  ... Patient Survey Star Rating Footnote  \
# 0  Summary star rating  ...                                 NaN
#
#   HCAHPS Answer Percent HCAHPS Answer Percent Footnote  \
# 0        Not Applicable                            NaN
#
#   HCAHPS Linear Mean Value Number of Completed Surveys  \
# 0           Not Applicable                         463
#
#   Number of Completed Surveys Footnote Survey Response Rate Percent  \
# 0                                  NaN                           20
#
#   Survey Response Rate Percent Footnote Measure Start Date Measure End Date
# 0                                   NaN         01/01/2017       12/31/2017
#
# ...

# %%
hcahps_2017.shape
# Out:
# (246450, 22)

# %%
hcahps_2017.dtypes
# Out:
# Provider ID                              object
# Hospital Name                            object
# Address                                  object
# City                                     object
# State                                    object
# ZIP Code                                  int64
# County Name                              object
# Phone Number                              int64
# HCAHPS Measure ID                        object
# HCAHPS Question                          object
# HCAHPS Answer Description                object
# Patient Survey Star Rating               object
# Patient Survey Star Rating Footnote      object
# HCAHPS Answer Percent                    object
# HCAHPS Answer Percent Footnote           object
# HCAHPS Linear Mean Value                 object
# Number of Completed Surveys              object
# Number of Completed Surveys Footnote     object
# Survey Response Rate Percent             object
# Survey Response Rate Percent Footnote    object
# ...

# %%
hcahps_2018 = pd.read_csv('../data/hcahps_2019.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\1348149062.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2018 = pd.read_csv('../data/hcahps_2019.csv')

# %%
hcahps_2018.head(1)
# Out:
#   Facility ID                     Facility Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_A_P
#
#                                      HCAHPS Question  ...  \
# 0  Patients who reported that their nurses "Alway...  ...
#
#   Patient Survey Star Rating Footnote HCAHPS Answer Percent  \
# 0                                 NaN                    74
#
#   HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 0                            NaN           Not Applicable
#
#   Number of Completed Surveys Number of Completed Surveys Footnote  \
# 0                         558                                  NaN
#
#   Survey Response Rate Percent Survey Response Rate Percent Footnote  \
# 0                           23                                   NaN
#
# ...

# %%
hcahps_2018.shape
# Out:
# (455142, 22)

# %%
hcahps_2019 = pd.read_csv('../data/hcahps_2020.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\2036856423.py:1: DtypeWarning: Columns (12,14,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2019 = pd.read_csv('../data/hcahps_2020.csv')

# %%
hcahps_2019.head(1)
# Out:
#   Facility ID                     Facility Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_A_P
#
#                                      HCAHPS Question  ...  \
# 0  Patients who reported that their nurses "Alway...  ...
#
#   Patient Survey Star Rating Footnote HCAHPS Answer Percent  \
# 0                                 NaN                    77
#
#   HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 0                            NaN           Not Applicable
#
#   Number of Completed Surveys Number of Completed Surveys Footnote  \
# 0                         507                                  NaN
#
#   Survey Response Rate Percent Survey Response Rate Percent Footnote  \
# 0                           21                                   NaN
#
# ...

# %%
hcahps_2019.shape
# Out:
# (453654, 22)

# %%
pd.set_option('display.max_columns', None)

# %%
hcahps_2020 = pd.read_csv('../data/hcahps_2021.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\890327871.py:1: DtypeWarning: Columns (12,14,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2020 = pd.read_csv('../data/hcahps_2021.csv')

# %%
hcahps_2020
# Out:
#        Facility ID                    Facility Name                 Address  \
# 0           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...            ...                              ...                     ...
# 451510      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451511      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451512      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451513      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451514      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
#
# ...

# %%
hcahps_2021 = pd.read_csv('../data/hcahps_2022.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\4275450306.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2021 = pd.read_csv('../data/hcahps_2022.csv')

# %%
hcahps_2021
# Out:
#        Facility ID                     Facility Name  \
# 0           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 1           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 2           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 3           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 4           010001   SOUTHEAST HEALTH MEDICAL CENTER
# ...            ...                               ...
# 450580      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 450581      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 450582      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 450583      670314  ST MICHAELS MEDICAL HOSPITAL LLC
# 450584      670314  ST MICHAELS MEDICAL HOSPITAL LLC
#
#                                    Address        City State  ZIP Code  \
# 0                   1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301
# 1                   1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301
# 2                   1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301
# ...

# %%
hcahps_2022 = pd.read_csv('../data/hcahps_2023.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\301312994.py:1: DtypeWarning: Columns (12,14,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2022 = pd.read_csv('../data/hcahps_2023.csv')

# %%
hcahps_2022
# Out:
#        Facility ID                     Facility Name  \
# 0           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 1           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 2           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 3           010001   SOUTHEAST HEALTH MEDICAL CENTER
# 4           010001   SOUTHEAST HEALTH MEDICAL CENTER
# ...            ...                               ...
# 449092      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 449093      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 449094      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 449095      670319  TRINITY REGIONAL HOSPITAL SACHSE
# 449096      670319  TRINITY REGIONAL HOSPITAL SACHSE
#
#                                    Address City/Town State  ZIP Code  \
# 0                   1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# 1                   1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# 2                   1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301
# ...

# %%
hcahps_2023 = pd.read_csv('../data/hcahps_2024.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\1046136080.py:1: DtypeWarning: Columns (12,14,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2023 = pd.read_csv('../data/hcahps_2024.csv')

# %%
hcahps_2023
# Out:
#        Facility ID                    Facility Name                 Address  \
# 0           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...            ...                              ...                     ...
# 444442      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 444443      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 444444      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 444445      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 444446      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
#
# ...

# %%
hcahps_2024 = pd.read_csv('../data/hcahps_2025.csv')
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\2603919946.py:1: DtypeWarning: Columns (12,14,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps_2024 = pd.read_csv('../data/hcahps_2025.csv')

# %%
hcahps_2024
# Out:
#        Facility ID                    Facility Name                 Address  \
# 0           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...            ...                              ...                     ...
# 442210      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442211      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442212      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442213      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442214      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
#
# ...

# %% [markdown]
# hcahps_2017

# %% [markdown]
# hcahps_2018

# %% [markdown]
# hcahps_2019

# %% [markdown]
# hcahps_2020

# %% [markdown]
# hcahps_2021

# %% [markdown]
# hcahps_2022

# %% [markdown]
# hcahps_2023

# %% [markdown]
# hcahps_2024

# %% [markdown]
# # *starting to clean the 2017 data

# %%
hcahps_2017
# Out:
#        Provider ID                     Hospital Name                 Address  \
# 0            10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1            10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2            10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3            10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4            10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...            ...                               ...                     ...
# 246445      53005F        SHERIDAN VA MEDICAL CENTER          1898 FORT ROAD
# 246446      53005F        SHERIDAN VA MEDICAL CENTER          1898 FORT ROAD
# 246447      53005F        SHERIDAN VA MEDICAL CENTER          1898 FORT ROAD
# 246448      53005F        SHERIDAN VA MEDICAL CENTER          1898 FORT ROAD
# 246449      53005F        SHERIDAN VA MEDICAL CENTER          1898 FORT ROAD
#
# ...

# %% [markdown]
# ### making all the column titles lowercase for easy use

# %%
hcahps_2017.columns = hcahps_2017.columns.str.lower()

# %%
hcahps_2017.head(1)
# Out:
#   provider id                     hospital name                 address  \
# 0       10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state  zip code county name  phone number hcahps measure id  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701     H_STAR_RATING
#
#        hcahps question hcahps answer description patient survey star rating  \
# 0  Summary star rating       Summary star rating                          2
#
#   patient survey star rating footnote hcahps answer percent  \
# 0                                 NaN        Not Applicable
#
#   hcahps answer percent footnote hcahps linear mean value  \
# 0                            NaN           Not Applicable
#
#   number of completed surveys number of completed surveys footnote  \
# 0                         463                                  NaN
#
#   survey response rate percent survey response rate percent footnote  \
# ...

# %% [markdown]
# ### filtering the data to just TN hospital with a new DF named hcahps_2017_tn

# %%
hcahps_2017_tn = hcahps_2017.loc[hcahps_2017['state'] == 'TN']

# %%
hcahps_2017_tn.reset_index()
# Out:
#        index provider id                          hospital name  \
# 0     191600      440001                UNICOI COUNTY  HOSPITAL
# 1     191601      440001                UNICOI COUNTY  HOSPITAL
# 2     191602      440001                UNICOI COUNTY  HOSPITAL
# 3     191603      440001                UNICOI COUNTY  HOSPITAL
# 4     191604      440001                UNICOI COUNTY  HOSPITAL
# ...      ...         ...                                    ...
# 5595  245395      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 5596  245396      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 5597  245397      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 5598  245398      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 5599  245399      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
#
#                      address       city state  zip code county name  \
# 0        100 GREENWAY CIRCLE      ERWIN    TN     37650      UNICOI
# ...

# %%
hcahps_2017_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2017_tn['measure end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\2558796000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2017_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2017_tn['measure end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2017_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5600 entries, 191600 to 245399
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   provider id                            5600 non-null   object
#  1   hospital name                          5600 non-null   object
#  2   address                                5600 non-null   object
#  3   city                                   5600 non-null   object
#  4   state                                  5600 non-null   object
#  5   zip code                               5600 non-null   int64
#  6   county name                            5600 non-null   object
#  7   phone number                           5600 non-null   int64
#  8   hcahps measure id                      5600 non-null   object
#  9   hcahps question                        5600 non-null   object
# ...

# %%
hcahps_2017_tn
# Out:
#        provider id                          hospital name  \
# 191600      440001                UNICOI COUNTY  HOSPITAL
# 191601      440001                UNICOI COUNTY  HOSPITAL
# 191602      440001                UNICOI COUNTY  HOSPITAL
# 191603      440001                UNICOI COUNTY  HOSPITAL
# 191604      440001                UNICOI COUNTY  HOSPITAL
# ...            ...                                    ...
# 245395      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245396      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245397      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245398      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245399      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
#
#                        address       city state  zip code county name  \
# 191600     100 GREENWAY CIRCLE      ERWIN    TN     37650      UNICOI
# 191601     100 GREENWAY CIRCLE      ERWIN    TN     37650      UNICOI
# ...

# %% [markdown]
# ### removing columns of phone number, measure start date, and measure end date. removing all but the year
# ### from the measure end date and renaming it year. dates were 1/1/17-12/31/17

# %%
hcahps_2017_tn = hcahps_2017_tn.drop(['phone number', 'measure start date', 'measure end date'], axis=1)

# %%
hcahps_2017_tn
# Out:
#        provider id                          hospital name  \
# 191600      440001                UNICOI COUNTY  HOSPITAL
# 191601      440001                UNICOI COUNTY  HOSPITAL
# 191602      440001                UNICOI COUNTY  HOSPITAL
# 191603      440001                UNICOI COUNTY  HOSPITAL
# 191604      440001                UNICOI COUNTY  HOSPITAL
# ...            ...                                    ...
# 245395      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245396      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245397      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245398      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
# 245399      44018F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
#
#                        address       city state  zip code county name  \
# 191600     100 GREENWAY CIRCLE      ERWIN    TN     37650      UNICOI
# 191601     100 GREENWAY CIRCLE      ERWIN    TN     37650      UNICOI
# ...

# %% [markdown]
# ### filtering out all rows except the rows for the star ratings per hosp in TN

# %%
all_star_rating_2017 = []
for index, row in hcahps_2017_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2017.append(row)
all_star_rating_2017 = pd.DataFrame(all_star_rating_2017)

# %%
all_star_rating_2017.head(50)
# Out:
#        provider id                            hospital name  \
# 191600      440001                  UNICOI COUNTY  HOSPITAL
# 191605      440001                  UNICOI COUNTY  HOSPITAL
# 191609      440001                  UNICOI COUNTY  HOSPITAL
# 191614      440001                  UNICOI COUNTY  HOSPITAL
# 191619      440001                  UNICOI COUNTY  HOSPITAL
# 191624      440001                  UNICOI COUNTY  HOSPITAL
# 191628      440001                  UNICOI COUNTY  HOSPITAL
# 191634      440001                  UNICOI COUNTY  HOSPITAL
# 191639      440001                  UNICOI COUNTY  HOSPITAL
# 191644      440001                  UNICOI COUNTY  HOSPITAL
# 191649      440001                  UNICOI COUNTY  HOSPITAL
# 191650      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 191655      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 191659      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 191664      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
# ...

# %%
all_star_rating_2017.to_csv('all_star_rating_2017.csv', index = False)

# %%
all_star_rating_2017.isnull().sum()
# Out:
# provider id                                 0
# hospital name                               0
# address                                     0
# city                                        0
# state                                       0
# zip code                                    0
# county name                                 0
# hcahps measure id                           0
# hcahps question                             0
# hcahps answer description                   0
# patient survey star rating                  0
# patient survey star rating footnote       924
# hcahps answer percent                       0
# hcahps answer percent footnote           1232
# hcahps linear mean value                    0
# number of completed surveys                 0
# number of completed surveys footnote      836
# survey response rate percent                0
# survey response rate percent footnote     836
# year                                        0
# dtype: int64

# %%
all_star_rating_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1232 entries, 191600 to 245399
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   provider id                            1232 non-null   object
#  1   hospital name                          1232 non-null   object
#  2   address                                1232 non-null   object
#  3   city                                   1232 non-null   object
#  4   state                                  1232 non-null   object
#  5   zip code                               1232 non-null   int64
#  6   county name                            1232 non-null   object
#  7   hcahps measure id                      1232 non-null   object
#  8   hcahps question                        1232 non-null   object
#  9   hcahps answer description              1232 non-null   object
# ...

# %%
all_star_rating_2017['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                486
# Not Available    308
# 4                255
# 2                115
# 5                 43
# 1                 25
# Name: count, dtype: int64

# %%
all_star_rating_2017['hospital name'].nunique()
# Out:
# 112

# %%
nsr_2017 = all_star_rating_2017.loc[all_star_rating_2017['patient survey star rating'] == 'Not Available']

# %%
nsr_2017['hospital name'].nunique()
# Out:
# 28

# %%
nsr_2017
# Out:
#        provider id                                      hospital name  \
# 191600      440001                            UNICOI COUNTY  HOSPITAL
# 191605      440001                            UNICOI COUNTY  HOSPITAL
# 191609      440001                            UNICOI COUNTY  HOSPITAL
# 191614      440001                            UNICOI COUNTY  HOSPITAL
# 191619      440001                            UNICOI COUNTY  HOSPITAL
# ...            ...                                                ...
# 245328      44017F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM - MURFRE...
# 245334      44017F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM - MURFRE...
# 245339      44017F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM - MURFRE...
# 245344      44017F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM - MURFRE...
# 245349      44017F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM - MURFRE...
#
#                     address          city state  zip code county name  \
# ...

# %%
nsr_2017['hcahps question'].value_counts()
# Out:
# hcahps question
# Summary star rating                            28
# Cleanliness - star rating                      28
# Nurse communication - star rating              28
# Doctor communication - star rating             28
# Staff responsiveness - star rating             28
# Communication about medicines - star rating    28
# Discharge information - star rating            28
# Care transition - star rating                  28
# Overall hospital rating - star rating          28
# Quietness - star rating                        28
# Recommend hospital - star rating               28
# Name: count, dtype: int64

# %% [markdown]
# ### decided to keep all hospitals in even if they do not have star ratings and can filter out later with the final DF

# %% [markdown]
# # Filtering by just Summary Star Rating for 2017

# %%
all_star_rating_2017.head(1)
# Out:
#        provider id            hospital name              address   city state  \
# 191600      440001  UNICOI COUNTY  HOSPITAL  100 GREENWAY CIRCLE  ERWIN    TN
#
#         zip code county name hcahps measure id      hcahps question  \
# 191600     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 191600       Summary star rating              Not Available
#
#                       patient survey star rating footnote  \
# 191600  15 - The number of cases/patients is too few t...
#
#        hcahps answer percent  hcahps answer percent footnote  \
# 191600        Not Applicable                             NaN
#
#        hcahps linear mean value number of completed surveys  \
# 191600           Not Applicable                          86
#
#                      number of completed surveys footnote  \
# 191600  6 - Fewer than 100 patients completed the HCAH...
#
#        survey response rate percent  \
# ...

# %%
summary_star_rating_2017 = []
for index, row in all_star_rating_2017.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2017.append(row)
summary_star_rating_2017 = pd.DataFrame(summary_star_rating_2017)

# %%
summary_star_rating_2017
# Out:
#        provider id                                      hospital name  \
# 191600      440001                            UNICOI COUNTY  HOSPITAL
# 191650      440002            JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 191700      440003                     SUMNER REGIONAL MEDICAL CENTER
# 191750      440006                     TRISTAR SKYLINE MEDICAL CENTER
# 191800      440007                               UNITY MEDICAL CENTER
# ...            ...                                                ...
# 196950      443303                  EAST TENNESSEE CHILDRENS HOSPITAL
# 245200      44013F                          MEMPHIS VA MEDICAL CENTER
# 245250      44016F                    MOUNTAIN HOME VA MEDICAL CENTER
# 245300      44017F  VA MIDDLE TENNESSEE HEALTHCARE SYSTEM - MURFRE...
# 245350      44018F              VA MIDDLE TENNESSEE HEALTHCARE SYSTEM
#
#                                          address           city state  \
# ...

# %%
summary_star_rating_2017['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                51
# Not Available    28
# 4                23
# 2                 6
# 5                 3
# 1                 1
# Name: count, dtype: int64

# %%
summary_star_rating_2017['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Cleaning star data for 2018 same as steps above with 2017

# %% [markdown]
# hcahps_2018

# %%
hcahps_2018.columns = hcahps_2018.columns.str.lower()

# %%
hcahps_2018.head(1)
# Out:
#   facility id                     facility name                 address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state  zip code county name    phone number hcahps measure id  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_A_P
#
#                                      hcahps question  \
# 0  Patients who reported that their nurses "Alway...
#
#            hcahps answer description patient survey star rating  \
# 0  Nurses "always" communicated well             Not Applicable
#
#   patient survey star rating footnote hcahps answer percent  \
# 0                                 NaN                    74
#
#   hcahps answer percent footnote hcahps linear mean value  \
# 0                            NaN           Not Applicable
#
#   number of completed surveys number of completed surveys footnote  \
# 0                         558                                  NaN
#
# ...

# %%
hcahps_2018_tn = hcahps_2018.loc[hcahps_2018['state'] == 'TN']

# %%
hcahps_2018_tn.head(1)
# Out:
#        facility id            facility name                address   city  \
# 364746      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name    phone number hcahps measure id  \
# 364746    TN     37650      UNICOI  (423) 743-3141      H_COMP_1_A_P
#
#                                           hcahps question  \
# 364746  Patients who reported that their nurses "Alway...
#
#                 hcahps answer description patient survey star rating  \
# 364746  Nurses "always" communicated well             Not Applicable
#
#        patient survey star rating footnote hcahps answer percent  \
# 364746                                 NaN                    83
#
#        hcahps answer percent footnote hcahps linear mean value  \
# 364746                              6           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# ...

# %%
hcahps_2018_tn.reset_index()
# Out:
#         index facility id                      facility name  \
# 0      364746      440001            UNICOI COUNTY  HOSPITAL
# 1      364747      440001            UNICOI COUNTY  HOSPITAL
# 2      364748      440001            UNICOI COUNTY  HOSPITAL
# 3      364749      440001            UNICOI COUNTY  HOSPITAL
# 4      364750      440001            UNICOI COUNTY  HOSPITAL
# ...       ...         ...                                ...
# 10132  374878      443303  EAST TENNESSEE CHILDRENS HOSPITAL
# 10133  374879      443303  EAST TENNESSEE CHILDRENS HOSPITAL
# 10134  374880      443303  EAST TENNESSEE CHILDRENS HOSPITAL
# 10135  374881      443303  EAST TENNESSEE CHILDRENS HOSPITAL
# 10136  374882      443303  EAST TENNESSEE CHILDRENS HOSPITAL
#
#                      address       city state  zip code county name  \
# 0      2030 TEMPLE HILL ROAD      ERWIN    TN     37650      UNICOI
# 1      2030 TEMPLE HILL ROAD      ERWIN    TN     37650      UNICOI
# ...

# %%
hcahps_2018_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2018_tn['end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\3213812677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2018_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2018_tn['end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2018_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10137 entries, 364746 to 374882
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   facility id                            10137 non-null  object
#  1   facility name                          10137 non-null  object
#  2   address                                10137 non-null  object
#  3   city                                   10137 non-null  object
#  4   state                                  10137 non-null  object
#  5   zip code                               10137 non-null  int64
#  6   county name                            10137 non-null  object
#  7   phone number                           10137 non-null  object
#  8   hcahps measure id                      10137 non-null  object
#  9   hcahps question                        10137 non-null  object
# ...

# %%
hcahps_2018_tn = hcahps_2018_tn.drop(['phone number', 'start date', 'end date'], axis=1)

# %%
hcahps_2018_tn.head(1)
# Out:
#        facility id            facility name                address   city  \
# 364746      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id  \
# 364746    TN     37650      UNICOI      H_COMP_1_A_P
#
#                                           hcahps question  \
# 364746  Patients who reported that their nurses "Alway...
#
#                 hcahps answer description patient survey star rating  \
# 364746  Nurses "always" communicated well             Not Applicable
#
#        patient survey star rating footnote hcahps answer percent  \
# 364746                                 NaN                    83
#
#        hcahps answer percent footnote hcahps linear mean value  \
# 364746                              6           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 364746                          72                                    6
#
# ...

# %%
all_star_rating_2018 = []
for index, row in hcahps_2018_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2018.append(row)
all_star_rating_2018 = pd.DataFrame(all_star_rating_2018)

# %%
all_star_rating_2018
# Out:
#        facility id                      facility name                address  \
# 364750      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 364764      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 364778      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 364789      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 364799      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 374866      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 374871      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 374876      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 374881      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 374882      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
all_star_rating_2018.to_csv('all_star_rating_2018.csv', index = False)

# %%
all_star_rating_2018['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                404
# Not Available    308
# 4                261
# 2                163
# 5                 38
# 1                 25
# Name: count, dtype: int64

# %%
summary_star_rating_2018 = []
for index, row in all_star_rating_2018.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2018.append(row)
summary_star_rating_2018 = pd.DataFrame(summary_star_rating_2018)

# %%
summary_star_rating_2018
# Out:
#        facility id                            facility name  \
# 364838      440001                  UNICOI COUNTY  HOSPITAL
# 364931      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 365024      440003           SUMNER REGIONAL MEDICAL CENTER
# 365117      440006           TRISTAR SKYLINE MEDICAL CENTER
# 365210      440007                     UNITY MEDICAL CENTER
# ...            ...                                      ...
# 374510      441319                CUMBERLAND RIVER HOSPITAL
# 374603      441320                 BOLIVAR GENERAL HOSPITAL
# 374696      441322        HOUSTON COUNTY COMMUNITY HOSPITAL
# 374789      443302      ST JUDE CHILDRENS RESEARCH HOSPITAL
# 374882      443303        EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address        city state  zip code county name  \
# 364838   2030 TEMPLE HILL ROAD       ERWIN    TN     37650      UNICOI
# 364931       620 SKYLINE DRIVE     JACKSON    TN     38301     MADISON
# ...

# %%
summary_star_rating_2018['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                38
# Not Available    28
# 4                27
# 2                14
# 5                 2
# Name: count, dtype: int64

# %%
summary_star_rating_2018['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Cleaning star data for 2019 same as steps above with 2018

# %% [markdown]
# hcahps_2019

# %%
hcahps_2019.columns = hcahps_2019.columns.str.lower()

# %%
hcahps_2019.head(1)
# Out:
#   facility id                     facility name                 address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state  zip code county name    phone number hcahps measure id  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_A_P
#
#                                      hcahps question  \
# 0  Patients who reported that their nurses "Alway...
#
#            hcahps answer description patient survey star rating  \
# 0  Nurses "always" communicated well             Not Applicable
#
#   patient survey star rating footnote hcahps answer percent  \
# 0                                 NaN                    77
#
#   hcahps answer percent footnote hcahps linear mean value  \
# 0                            NaN           Not Applicable
#
#   number of completed surveys number of completed surveys footnote  \
# 0                         507                                  NaN
#
# ...

# %% [markdown]
# ### filterinf out just TN hosp

# %%
hcahps_2019_tn = hcahps_2019.loc[hcahps_2019['state'] == 'TN']

# %%
hcahps_2019_tn
# Out:
#        facility id                      facility name                address  \
# 363909      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363910      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363911      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363912      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363913      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 373669      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373670      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373671      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373672      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373673      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
hcahps_2019_tn.reset_index().head(2)
# Out:
#     index facility id            facility name                address   city  \
# 0  363909      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
# 1  363910      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#   state  zip code county name    phone number hcahps measure id  \
# 0    TN     37650      UNICOI  (423) 743-3141      H_COMP_1_A_P
# 1    TN     37650      UNICOI  (423) 743-3141     H_COMP_1_SN_P
#
#                                      hcahps question  \
# 0  Patients who reported that their nurses "Alway...
# 1  Patients who reported that their nurses "Somet...
#
#                          hcahps answer description patient survey star rating  \
# 0                Nurses "always" communicated well             Not Applicable
# 1  Nurses "sometimes" or "never" communicated well             Not Applicable
#
#   patient survey star rating footnote hcahps answer percent  \
# 0                                 NaN                    86
# ...

# %%
hcahps_2019_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2019_tn['end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\3506460432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2019_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2019_tn['end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2019_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9765 entries, 363909 to 373673
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   facility id                            9765 non-null   object
#  1   facility name                          9765 non-null   object
#  2   address                                9765 non-null   object
#  3   city                                   9765 non-null   object
#  4   state                                  9765 non-null   object
#  5   zip code                               9765 non-null   int64
#  6   county name                            9765 non-null   object
#  7   phone number                           9765 non-null   object
#  8   hcahps measure id                      9765 non-null   object
#  9   hcahps question                        9765 non-null   object
# ...

# %%
hcahps_2019_tn = hcahps_2019_tn.drop(['phone number', 'start date', 'end date'], axis=1)

# %%
hcahps_2019_tn.head(2)
# Out:
#        facility id            facility name                address   city  \
# 363909      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
# 363910      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id  \
# 363909    TN     37650      UNICOI      H_COMP_1_A_P
# 363910    TN     37650      UNICOI     H_COMP_1_SN_P
#
#                                           hcahps question  \
# 363909  Patients who reported that their nurses "Alway...
# 363910  Patients who reported that their nurses "Somet...
#
#                               hcahps answer description  \
# 363909                Nurses "always" communicated well
# 363910  Nurses "sometimes" or "never" communicated well
#
#        patient survey star rating patient survey star rating footnote  \
# 363909             Not Applicable                                 NaN
# 363910             Not Applicable                                 NaN
#
# ...

# %%
all_star_rating_2019 = []
for index, row in hcahps_2019_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2019.append(row)
all_star_rating_2019 = pd.DataFrame(all_star_rating_2019)

# %%
all_star_rating_2019
# Out:
#        facility id                      facility name                address  \
# 363913      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363927      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363941      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363952      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 363962      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 373657      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373662      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373667      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373672      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 373673      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
all_star_rating_2019.to_csv('all_star_rating_2019.csv', index = False)

# %%
all_star_rating_2019['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                332
# Not Available    308
# 4                234
# 2                197
# 5                 48
# 1                 36
# Name: count, dtype: int64

# %%
summary_star_rating_2019 = []
for index, row in all_star_rating_2019.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2019.append(row)
summary_star_rating_2019 = pd.DataFrame(summary_star_rating_2019)

# %%
summary_star_rating_2019
# Out:
#        facility id                            facility name  \
# 364001      440001                  UNICOI COUNTY  HOSPITAL
# 364094      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 364187      440003           SUMNER REGIONAL MEDICAL CENTER
# 364280      440006           TRISTAR SKYLINE MEDICAL CENTER
# 364373      440007                     UNITY MEDICAL CENTER
# ...            ...                                      ...
# 373301      441316                  CAMDEN GENERAL HOSPITAL
# 373394      441320                 BOLIVAR GENERAL HOSPITAL
# 373487      441322        HOUSTON COUNTY COMMUNITY HOSPITAL
# 373580      443302      ST JUDE CHILDRENS RESEARCH HOSPITAL
# 373673      443303        EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address        city state  zip code county name  \
# 364001   2030 TEMPLE HILL ROAD       ERWIN    TN     37650      UNICOI
# 364094       620 SKYLINE DRIVE     JACKSON    TN     38301     MADISON
# ...

# %%
summary_star_rating_2019['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                39
# Not Available    28
# 4                20
# 2                14
# 1                 2
# 5                 2
# Name: count, dtype: int64

# %%
summary_star_rating_2019['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Cleaning star data for 2020 same as steps above with 2019

# %%
hcahps_2020.columns = hcahps_2020.columns.str.lower()

# %%
hcahps_2020
# Out:
#        facility id                    facility name                 address  \
# 0           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...            ...                              ...                     ...
# 451510      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451511      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451512      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451513      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
# 451514      670285      KINGWOOD EMERGENCY HOSPITAL      23330 HIGHWAY 59 N
#
# ...

# %%
hcahps_2020_tn = hcahps_2020.loc[hcahps_2020['state'] == 'TN']

# %%
hcahps_2020_tn.head(2)
# Out:
#        facility id            facility name                address   city  \
# 361956      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
# 361957      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name    phone number hcahps measure id  \
# 361956    TN     37650      Unicoi  (423) 743-3141      H_COMP_1_A_P
# 361957    TN     37650      Unicoi  (423) 743-3141     H_COMP_1_SN_P
#
#                                           hcahps question  \
# 361956  Patients who reported that their nurses "Alway...
# 361957  Patients who reported that their nurses "Somet...
#
#                               hcahps answer description  \
# 361956                Nurses "always" communicated well
# 361957  Nurses "sometimes" or "never" communicated well
#
#        patient survey star rating patient survey star rating footnote  \
# 361956             Not Applicable                                 NaN
# ...

# %%
hcahps_2020_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2020_tn['end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\3441820350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2020_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2020_tn['end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2020_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9579 entries, 361956 to 371534
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   facility id                            9579 non-null   object
#  1   facility name                          9579 non-null   object
#  2   address                                9579 non-null   object
#  3   city                                   9579 non-null   object
#  4   state                                  9579 non-null   object
#  5   zip code                               9579 non-null   int64
#  6   county name                            9579 non-null   object
#  7   phone number                           9579 non-null   object
#  8   hcahps measure id                      9579 non-null   object
#  9   hcahps question                        9579 non-null   object
# ...

# %%
hcahps_2020_tn = hcahps_2020_tn.drop(['phone number', 'start date', 'end date'], axis=1)

# %%
hcahps_2020_tn.head(2)
# Out:
#        facility id            facility name                address   city  \
# 361956      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
# 361957      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id  \
# 361956    TN     37650      Unicoi      H_COMP_1_A_P
# 361957    TN     37650      Unicoi     H_COMP_1_SN_P
#
#                                           hcahps question  \
# 361956  Patients who reported that their nurses "Alway...
# 361957  Patients who reported that their nurses "Somet...
#
#                               hcahps answer description  \
# 361956                Nurses "always" communicated well
# 361957  Nurses "sometimes" or "never" communicated well
#
#        patient survey star rating patient survey star rating footnote  \
# 361956             Not Applicable                                 NaN
# 361957             Not Applicable                                 NaN
#
# ...

# %%
all_star_rating_2020 = []
for index, row in hcahps_2020_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2020.append(row)
all_star_rating_2020 = pd.DataFrame(all_star_rating_2020)

# %%
all_star_rating_2020
# Out:
#        facility id                      facility name                address  \
# 361960      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 361974      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 361988      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 361999      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 362009      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 371518      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 371523      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 371528      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 371533      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 371534      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
all_star_rating_2020.to_csv('all_star_rating_2020.csv', index = False)

# %%
all_star_rating_2020['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# Not Available    451
# 3                285
# 2                181
# 4                156
# 1                 32
# 5                 28
# Name: count, dtype: int64

# %%
summary_star_rating_2020 = []
for index, row in all_star_rating_2020.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2020.append(row)
summary_star_rating_2020 = pd.DataFrame(summary_star_rating_2020)

# %%
summary_star_rating_2020
# Out:
#        facility id                            facility name  \
# 362048      440001                  UNICOI COUNTY  HOSPITAL
# 362141      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 362234      440003           SUMNER REGIONAL MEDICAL CENTER
# 362327      440006           TRISTAR SKYLINE MEDICAL CENTER
# 362420      440007                     UNITY MEDICAL CENTER
# ...            ...                                      ...
# 371162      441316                  CAMDEN GENERAL HOSPITAL
# 371255      441320                 BOLIVAR GENERAL HOSPITAL
# 371348      441322        HOUSTON COUNTY COMMUNITY HOSPITAL
# 371441      443302      ST JUDE CHILDRENS RESEARCH HOSPITAL
# 371534      443303        EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address        city state  zip code county name  \
# 362048   2030 TEMPLE HILL ROAD       ERWIN    TN     37650      Unicoi
# 362141       620 SKYLINE DRIVE     JACKSON    TN     38301     Madison
# ...

# %%
summary_star_rating_2020['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# Not Available    41
# 3                32
# 2                17
# 4                11
# 5                 2
# Name: count, dtype: int64

# %%
summary_star_rating_2020['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Cleaning star data for 2021 same as steps above with 2020

# %%
hcahps_2021.head(2)
# Out:
#   Facility ID                    Facility Name                 Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701      H_COMP_1_A_P
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701     H_COMP_1_SN_P
#
#                                      HCAHPS Question  \
# 0  Patients who reported that their nurses "Alway...
# 1  Patients who reported that their nurses "Somet...
#
#                          HCAHPS Answer Description Patient Survey Star Rating  \
# 0                Nurses "always" communicated well             Not Applicable
# 1  Nurses "sometimes" or "never" communicated well             Not Applicable
#
#   Patient Survey Star Rating Footnote HCAHPS Answer Percent  \
# 0                                 NaN                    77
# ...

# %%
hcahps_2021.columns = hcahps_2021.columns.str.lower()

# %%
hcahps_2021_tn = hcahps_2021.loc[hcahps_2021['state'] == 'TN']

# %%
hcahps_2021_tn.head(2)
# Out:
#        facility id            facility name                address   city  \
# 361305      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
# 361306      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name    phone number hcahps measure id  \
# 361305    TN     37650      UNICOI  (423) 743-3141      H_COMP_1_A_P
# 361306    TN     37650      UNICOI  (423) 743-3141     H_COMP_1_SN_P
#
#                                           hcahps question  \
# 361305  Patients who reported that their nurses "Alway...
# 361306  Patients who reported that their nurses "Somet...
#
#                               hcahps answer description  \
# 361305                Nurses "always" communicated well
# 361306  Nurses "sometimes" or "never" communicated well
#
#        patient survey star rating patient survey star rating footnote  \
# 361305             Not Applicable                                 NaN
# ...

# %%
hcahps_2021_tn.reset_index(drop=True)
# Out:
#      facility id                      facility name                address  \
# 0         440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 1         440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 2         440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 3         440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 4         440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...          ...                                ...                    ...
# 9481      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 9482      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 9483      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 9484      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 9485      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
#            city state  zip code county name    phone number  \
# ...

# %%
hcahps_2021_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2021_tn['end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\1226984985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2021_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2021_tn['end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2021_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9486 entries, 361305 to 370790
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   facility id                            9486 non-null   object
#  1   facility name                          9486 non-null   object
#  2   address                                9486 non-null   object
#  3   city                                   9486 non-null   object
#  4   state                                  9486 non-null   object
#  5   zip code                               9486 non-null   int64
#  6   county name                            9486 non-null   object
#  7   phone number                           9486 non-null   object
#  8   hcahps measure id                      9486 non-null   object
#  9   hcahps question                        9486 non-null   object
# ...

# %%
hcahps_2021_tn = hcahps_2021_tn.drop(['phone number', 'start date', 'end date'], axis=1)

# %%
hcahps_2021_tn.head(1)
# Out:
#        facility id            facility name                address   city  \
# 361305      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id  \
# 361305    TN     37650      UNICOI      H_COMP_1_A_P
#
#                                           hcahps question  \
# 361305  Patients who reported that their nurses "Alway...
#
#                 hcahps answer description patient survey star rating  \
# 361305  Nurses "always" communicated well             Not Applicable
#
#        patient survey star rating footnote hcahps answer percent  \
# 361305                                 NaN                    84
#
#        hcahps answer percent footnote hcahps linear mean value  \
# 361305                             10           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 361305                          49                                   10
#
# ...

# %%
all_star_rating_2021 = []
for index, row in hcahps_2021_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2021.append(row)
all_star_rating_2021 = pd.DataFrame(all_star_rating_2021)

# %%
all_star_rating_2021
# Out:
#        facility id                      facility name                address  \
# 361309      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 361323      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 361337      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 361348      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 361358      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 370774      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 370779      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 370784      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 370789      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 370790      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
all_star_rating_2021.to_csv('all_star_rating_2021.csv', index = False)

# %%
all_star_rating_2021['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                380
# Not Available    308
# 4                200
# 2                149
# 5                 50
# 1                 35
# Name: count, dtype: int64

# %%
summary_star_rating_2021 = []
for index, row in all_star_rating_2021.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2021.append(row)
summary_star_rating_2021 = pd.DataFrame(summary_star_rating_2021)

# %%
summary_star_rating_2021
# Out:
#        facility id                               facility name  \
# 361397      440001                     UNICOI COUNTY  HOSPITAL
# 361490      440002     JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 361583      440003              SUMNER REGIONAL MEDICAL CENTER
# 361676      440006              TRISTAR SKYLINE MEDICAL CENTER
# 361769      440007                        UNITY MEDICAL CENTER
# ...            ...                                         ...
# 370418      441320  WEST TENNESSEE HEALTHCARE BOLIVAR HOSPITAL
# 370511      441322           HOUSTON COUNTY COMMUNITY HOSPITAL
# 370604      441323               BIG SOUTH FORK MEDICAL CENTER
# 370697      443302         ST JUDE CHILDRENS RESEARCH HOSPITAL
# 370790      443303           EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address        city state  zip code county name  \
# 361397   2030 TEMPLE HILL ROAD       ERWIN    TN     37650      UNICOI
# ...

# %%
summary_star_rating_2021['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                40
# Not Available    28
# 4                17
# 2                13
# 5                 3
# 1                 1
# Name: count, dtype: int64

# %%
summary_star_rating_2021['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Cleaning star data for 2022 same as steps above with 2021

# %%
hcahps_2022.head(2)
# Out:
#   Facility ID                    Facility Name                 Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   City/Town State  ZIP Code County/Parish Telephone Number HCAHPS Measure ID  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701      H_COMP_1_A_P
# 1    DOTHAN    AL     36301       HOUSTON   (334) 793-8701     H_COMP_1_SN_P
#
#                                      HCAHPS Question  \
# 0  Patients who reported that their nurses "Alway...
# 1  Patients who reported that their nurses "Somet...
#
#                          HCAHPS Answer Description Patient Survey Star Rating  \
# 0                Nurses "always" communicated well             Not Applicable
# 1  Nurses "sometimes" or "never" communicated well             Not Applicable
#
#   Patient Survey Star Rating Footnote HCAHPS Answer Percent  \
# ...

# %%
hcahps_2022.columns = hcahps_2022.columns.str.lower()

# %%
hcahps_2022.head(1)
# Out:
#   facility id                    facility name                 address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   city/town state  zip code county/parish telephone number hcahps measure id  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701      H_COMP_1_A_P
#
#                                      hcahps question  \
# 0  Patients who reported that their nurses "Alway...
#
#            hcahps answer description patient survey star rating  \
# 0  Nurses "always" communicated well             Not Applicable
#
#   patient survey star rating footnote hcahps answer percent  \
# 0                                 NaN                    74
#
#   hcahps answer percent footnote hcahps linear mean value  \
# 0                            NaN           Not Applicable
#
#   number of completed surveys number of completed surveys footnote  \
# 0                         536                                  NaN
#
# ...

# %%
hcahps_2022_tn = hcahps_2022.loc[hcahps_2022['state'] == 'TN']

# %%
hcahps_2022_tn
# Out:
#        facility id                      facility name                address  \
# 359910      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359911      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359912      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359913      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359914      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 369484      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369485      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369486      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369487      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369488      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
hcahps_2022_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2022_tn['end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\3048071030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2022_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2022_tn['end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2022_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9579 entries, 359910 to 369488
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   facility id                            9579 non-null   object
#  1   facility name                          9579 non-null   object
#  2   address                                9579 non-null   object
#  3   city/town                              9579 non-null   object
#  4   state                                  9579 non-null   object
#  5   zip code                               9579 non-null   int64
#  6   county/parish                          9579 non-null   object
#  7   telephone number                       9579 non-null   object
#  8   hcahps measure id                      9579 non-null   object
#  9   hcahps question                        9579 non-null   object
# ...

# %%
hcahps_2022_tn = hcahps_2022_tn.drop(['telephone number', 'start date', 'end date'], axis=1)

# %%
hcahps_2022_tn.head(1)
# Out:
#        facility id            facility name                address city/town  \
# 359910      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD     ERWIN
#
#        state  zip code county/parish hcahps measure id  \
# 359910    TN     37650        UNICOI      H_COMP_1_A_P
#
#                                           hcahps question  \
# 359910  Patients who reported that their nurses "Alway...
#
#                 hcahps answer description patient survey star rating  \
# 359910  Nurses "always" communicated well             Not Applicable
#
#        patient survey star rating footnote hcahps answer percent  \
# 359910                                 NaN                    85
#
#        hcahps answer percent footnote hcahps linear mean value  \
# 359910                              6           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 359910                          74                                    6
#
# ...

# %%
all_star_rating_2022 = []
for index, row in hcahps_2022_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2022.append(row)
all_star_rating_2022 = pd.DataFrame(all_star_rating_2022)

# %%
all_star_rating_2022
# Out:
#        facility id                      facility name                address  \
# 359914      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359928      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359942      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359953      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 359963      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 369472      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369477      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369482      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369487      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 369488      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
all_star_rating_2022.to_csv('all_star_rating_2022.csv', index = False)

# %%
all_star_rating_2022['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                359
# Not Available    297
# 4                228
# 2                151
# 5                 72
# 1                 26
# Name: count, dtype: int64

# %%
summary_star_rating_2022 = []
for index, row in all_star_rating_2022.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2022.append(row)
summary_star_rating_2022 = pd.DataFrame(summary_star_rating_2022)

# %%
summary_star_rating_2022
# Out:
#        facility id                               facility name  \
# 360002      440001                     UNICOI COUNTY  HOSPITAL
# 360095      440002     JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 360188      440003              SUMNER REGIONAL MEDICAL CENTER
# 360281      440006              TRISTAR SKYLINE MEDICAL CENTER
# 360374      440007                        UNITY MEDICAL CENTER
# ...            ...                                         ...
# 369116      441320  WEST TENNESSEE HEALTHCARE BOLIVAR HOSPITAL
# 369209      441322           HOUSTON COUNTY COMMUNITY HOSPITAL
# 369302      441323               BIG SOUTH FORK MEDICAL CENTER
# 369395      443302         ST JUDE CHILDRENS RESEARCH HOSPITAL
# 369488      443303           EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address   city/town state  zip code county/parish  \
# 360002   2030 TEMPLE HILL ROAD       ERWIN    TN     37650        UNICOI
# ...

# %%
summary_star_rating_2022['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                37
# Not Available    27
# 4                22
# 2                13
# 5                 4
# Name: count, dtype: int64

# %%
summary_star_rating_2022['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Cleaning star data for 2023 same as steps above with 2022

# %%
hcahps_2023.head(1)
# Out:
#   Facility ID                    Facility Name                 Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   City/Town State  ZIP Code County/Parish Telephone Number HCAHPS Measure ID  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701      H_COMP_1_A_P
#
#                                      HCAHPS Question  \
# 0  Patients who reported that their nurses "Alway...
#
#            HCAHPS Answer Description Patient Survey Star Rating  \
# 0  Nurses "always" communicated well             Not Applicable
#
#   Patient Survey Star Rating Footnote HCAHPS Answer Percent  \
# 0                                 NaN                    72
#
#   HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 0                            NaN           Not Applicable
#
#   Number of Completed Surveys Number of Completed Surveys Footnote  \
# 0                         643                                  NaN
#
# ...

# %%
hcahps_2023.columns = hcahps_2023.columns.str.lower()

# %%
hcahps_2023.head(1)
# Out:
#   facility id                    facility name                 address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   city/town state  zip code county/parish telephone number hcahps measure id  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701      H_COMP_1_A_P
#
#                                      hcahps question  \
# 0  Patients who reported that their nurses "Alway...
#
#            hcahps answer description patient survey star rating  \
# 0  Nurses "always" communicated well             Not Applicable
#
#   patient survey star rating footnote hcahps answer percent  \
# 0                                 NaN                    72
#
#   hcahps answer percent footnote hcahps linear mean value  \
# 0                            NaN           Not Applicable
#
#   number of completed surveys number of completed surveys footnote  \
# 0                         643                                  NaN
#
# ...

# %%
hcahps_2023_tn = hcahps_2023.loc[hcahps_2023['state'] == 'TN']

# %%
hcahps_2023_tn
# Out:
#        facility id                      facility name                address  \
# 356004      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356005      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356006      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356007      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356008      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 365485      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365486      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365487      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365488      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365489      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
hcahps_2023_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2023_tn['end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\960928366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2023_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2023_tn['end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2023_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9486 entries, 356004 to 365489
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   facility id                            9486 non-null   object
#  1   facility name                          9486 non-null   object
#  2   address                                9486 non-null   object
#  3   city/town                              9486 non-null   object
#  4   state                                  9486 non-null   object
#  5   zip code                               9486 non-null   int64
#  6   county/parish                          9486 non-null   object
#  7   telephone number                       9486 non-null   object
#  8   hcahps measure id                      9486 non-null   object
#  9   hcahps question                        9486 non-null   object
# ...

# %%
hcahps_2023_tn = hcahps_2023_tn.drop(['telephone number', 'start date', 'end date'], axis=1)

# %%
hcahps_2023_tn.head(1)
# Out:
#        facility id            facility name                address city/town  \
# 356004      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD     ERWIN
#
#        state  zip code county/parish hcahps measure id  \
# 356004    TN     37650        UNICOI      H_COMP_1_A_P
#
#                                           hcahps question  \
# 356004  Patients who reported that their nurses "Alway...
#
#                 hcahps answer description patient survey star rating  \
# 356004  Nurses "always" communicated well             Not Applicable
#
#        patient survey star rating footnote hcahps answer percent  \
# 356004                                 NaN                    90
#
#        hcahps answer percent footnote hcahps linear mean value  \
# 356004                              6           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 356004                          94                                    6
#
# ...

# %%
all_star_rating_2023 = []
for index, row in hcahps_2023_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2023.append(row)
all_star_rating_2023 = pd.DataFrame(all_star_rating_2023)

# %%
all_star_rating_2023
# Out:
#        facility id                      facility name                address  \
# 356008      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356022      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356036      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356047      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 356057      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 365473      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365478      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365483      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365488      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 365489      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
all_star_rating_2023.to_csv('all_star_rating_2023.csv', index = False)

# %%
all_star_rating_2023['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                316
# Not Available    308
# 4                240
# 2                167
# 5                 59
# 1                 32
# Name: count, dtype: int64

# %%
summary_star_rating_2023 = []
for index, row in all_star_rating_2023.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2023.append(row)
summary_star_rating_2023 = pd.DataFrame(summary_star_rating_2023)

# %%
summary_star_rating_2023
# Out:
#        facility id                               facility name  \
# 356096      440001                     UNICOI COUNTY  HOSPITAL
# 356189      440002     JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 356282      440003              SUMNER REGIONAL MEDICAL CENTER
# 356375      440006              TRISTAR SKYLINE MEDICAL CENTER
# 356468      440007                        UNITY MEDICAL CENTER
# ...            ...                                         ...
# 365117      441320  WEST TENNESSEE HEALTHCARE BOLIVAR HOSPITAL
# 365210      441322           HOUSTON COUNTY COMMUNITY HOSPITAL
# 365303      441323               BIG SOUTH FORK MEDICAL CENTER
# 365396      443302         ST JUDE CHILDRENS RESEARCH HOSPITAL
# 365489      443303           EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address   city/town state  zip code county/parish  \
# 356096   2030 TEMPLE HILL ROAD       ERWIN    TN     37650        UNICOI
# ...

# %%
summary_star_rating_2023['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                33
# Not Available    28
# 4                25
# 2                11
# 5                 3
# 1                 2
# Name: count, dtype: int64

# %%
summary_star_rating_2023['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Cleaning star data for 2024 same as steps above with 2023

# %%
hcahps_2024
# Out:
#        Facility ID                    Facility Name                 Address  \
# 0           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4           010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...            ...                              ...                     ...
# 442210      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442211      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442212      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442213      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
# 442214      671301         HEMPHILL COUNTY HOSPITAL           1020 S 4TH ST
#
# ...

# %%
hcahps_2024.columns = hcahps_2024.columns.str.lower()

# %%
hcahps_2024_tn = hcahps_2024.loc[hcahps_2024['state'] == 'TN']

# %%
hcahps_2024_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2024_tn['end date'], format="%m/%d/%Y").dt.year
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\798299131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcahps_2024_tn.loc[:, 'year'] = pd.to_datetime(hcahps_2024_tn['end date'], format="%m/%d/%Y").dt.year

# %%
hcahps_2024_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9300 entries, 354051 to 363350
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   facility id                            9300 non-null   object
#  1   facility name                          9300 non-null   object
#  2   address                                9300 non-null   object
#  3   city/town                              9300 non-null   object
#  4   state                                  9300 non-null   object
#  5   zip code                               9300 non-null   int64
#  6   county/parish                          9300 non-null   object
#  7   telephone number                       9300 non-null   object
#  8   hcahps measure id                      9300 non-null   object
#  9   hcahps question                        9300 non-null   object
# ...

# %%
hcahps_2024_tn = hcahps_2024_tn.drop(['telephone number', 'start date', 'end date'], axis=1)

# %%
all_star_rating_2024 = []
for index, row in hcahps_2024_tn.iterrows():
    if 'STAR_RATING' in row['hcahps measure id']:
        all_star_rating_2024.append(row)
all_star_rating_2024 = pd.DataFrame(all_star_rating_2024)

# %%
all_star_rating_2024
# Out:
#        facility id                      facility name                address  \
# 354055      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 354069      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 354083      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 354094      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# 354104      440001            UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD
# ...            ...                                ...                    ...
# 363334      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 363339      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 363344      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 363349      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
# 363350      443303  EAST TENNESSEE CHILDRENS HOSPITAL     2018 CLINCH AVE SW
#
# ...

# %%
all_star_rating_2024.to_csv('all_star_rating_2024.csv', index = False)

# %%
all_star_rating_2024['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                337
# Not Available    308
# 4                197
# 2                162
# 5                 64
# 1                 32
# Name: count, dtype: int64

# %%
summary_star_rating_2024 = []
for index, row in all_star_rating_2024.iterrows():
    if 'Summary star rating' in row['hcahps answer description']:
        summary_star_rating_2024.append(row)
summary_star_rating_2024 = pd.DataFrame(summary_star_rating_2024)

# %%
summary_star_rating_2024
# Out:
#        facility id                                      facility name  \
# 354143      440001                            UNICOI COUNTY  HOSPITAL
# 354236      440002            JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 354329      440003  HIGHPOINT HEALTH-SUMNER WITH ASCENSION SAINT T...
# 354422      440006                     TRISTAR SKYLINE MEDICAL CENTER
# 354515      440007                               UNITY MEDICAL CENTER
# ...            ...                                                ...
# 362978      441320         WEST TENNESSEE HEALTHCARE BOLIVAR HOSPITAL
# 363071      441322                  HOUSTON COUNTY COMMUNITY HOSPITAL
# 363164      441323                      BIG SOUTH FORK MEDICAL CENTER
# 363257      443302                ST JUDE CHILDRENS RESEARCH HOSPITAL
# 363350      443303                  EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address   city/town state  zip code county/parish  \
# ...

# %%
summary_star_rating_2024['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                31
# Not Available    28
# 4                24
# 2                11
# 5                 4
# 1                 2
# Name: count, dtype: int64

# %%
summary_star_rating_2024['patient survey star rating'].value_counts().plot(kind = 'barh');

# %% [markdown]
# # Concating all the summary star rating years together to 1 DF and renaming the columns to match

# %%
summary_star_rating_2017.head(1)
# Out:
#        provider id            hospital name              address   city state  \
# 191600      440001  UNICOI COUNTY  HOSPITAL  100 GREENWAY CIRCLE  ERWIN    TN
#
#         zip code county name hcahps measure id      hcahps question  \
# 191600     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 191600       Summary star rating              Not Available
#
#                       patient survey star rating footnote  \
# 191600  15 - The number of cases/patients is too few t...
#
#        hcahps answer percent  hcahps answer percent footnote  \
# 191600        Not Applicable                             NaN
#
#        hcahps linear mean value number of completed surveys  \
# 191600           Not Applicable                          86
#
#                      number of completed surveys footnote  \
# 191600  6 - Fewer than 100 patients completed the HCAH...
#
#        survey response rate percent  \
# ...

# %%
summary_star_rating_2017 = summary_star_rating_2017.rename(columns = {'provider id': 'facility id', 'hospital name':'facility name' }) 
#changed the provider ID column to facility ID  and hospital name to facility name to match all the others

# %%
summary_star_rating_2017.head(1)
# Out:
#        facility id            facility name              address   city state  \
# 191600      440001  UNICOI COUNTY  HOSPITAL  100 GREENWAY CIRCLE  ERWIN    TN
#
#         zip code county name hcahps measure id      hcahps question  \
# 191600     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 191600       Summary star rating              Not Available
#
#                       patient survey star rating footnote  \
# 191600  15 - The number of cases/patients is too few t...
#
#        hcahps answer percent  hcahps answer percent footnote  \
# 191600        Not Applicable                             NaN
#
#        hcahps linear mean value number of completed surveys  \
# 191600           Not Applicable                          86
#
#                      number of completed surveys footnote  \
# 191600  6 - Fewer than 100 patients completed the HCAH...
#
#        survey response rate percent  \
# ...

# %%
summary_star_rating_2018.head(1)
# Out:
#        facility id            facility name                address   city  \
# 364838      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id      hcahps question  \
# 364838    TN     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 364838       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 364838                                  15        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 364838                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 364838                          72                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2019.head(1)
# Out:
#        facility id            facility name                address   city  \
# 364001      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id      hcahps question  \
# 364001    TN     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 364001       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 364001                                  15        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 364001                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 364001                          90                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2020.head(1)
# Out:
#        facility id            facility name                address   city  \
# 362048      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id      hcahps question  \
# 362048    TN     37650      Unicoi     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 362048       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 362048                                  15        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 362048                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 362048               Not Available                                    1
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2021.head(1)
# Out:
#        facility id            facility name                address   city  \
# 361397      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id      hcahps question  \
# 361397    TN     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 361397       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 361397                                  15        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 361397                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 361397                          49                                   10
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2022.head(1)
# Out:
#        facility id            facility name                address city/town  \
# 360002      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD     ERWIN
#
#        state  zip code county/parish hcahps measure id      hcahps question  \
# 360002    TN     37650        UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 360002       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 360002                                  15        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 360002                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 360002                          74                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2022 = summary_star_rating_2022.rename(columns = {'county/parish': 'county name', 'city/town': 'city'}) 
#changed thecounty/parish column to county name to match all the others

# %%
summary_star_rating_2022.head(1)
# Out:
#        facility id            facility name                address   city  \
# 360002      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id      hcahps question  \
# 360002    TN     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 360002       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 360002                                  15        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 360002                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 360002                          74                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2023.head(1)
# Out:
#        facility id            facility name                address city/town  \
# 356096      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD     ERWIN
#
#        state  zip code county/parish hcahps measure id      hcahps question  \
# 356096    TN     37650        UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 356096       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 356096                                15.0        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 356096                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 356096                          94                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2023 = summary_star_rating_2023.rename(columns = {'city/town': 'city'}) 
#changed city/town column to city to match all the others

# %%
summary_star_rating_2023.head(1)
# Out:
#        facility id            facility name                address   city  \
# 356096      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county/parish hcahps measure id      hcahps question  \
# 356096    TN     37650        UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 356096       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 356096                                15.0        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 356096                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 356096                          94                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2023 = summary_star_rating_2023.rename(columns = {'county/parish': 'county name'}) 
#changed thecounty/parish column to county name to match all the others

# %%
summary_star_rating_2023.head(1)
# Out:
#        facility id            facility name                address   city  \
# 356096      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD  ERWIN
#
#        state  zip code county name hcahps measure id      hcahps question  \
# 356096    TN     37650      UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 356096       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 356096                                15.0        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 356096                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 356096                          94                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2024.head(1)
# Out:
#        facility id            facility name                address city/town  \
# 354143      440001  UNICOI COUNTY  HOSPITAL  2030 TEMPLE HILL ROAD     ERWIN
#
#        state  zip code county/parish hcahps measure id      hcahps question  \
# 354143    TN     37650        UNICOI     H_STAR_RATING  Summary star rating
#
#        hcahps answer description patient survey star rating  \
# 354143       Summary star rating              Not Available
#
#        patient survey star rating footnote hcahps answer percent  \
# 354143                                  15        Not Applicable
#
#         hcahps answer percent footnote hcahps linear mean value  \
# 354143                             NaN           Not Applicable
#
#        number of completed surveys number of completed surveys footnote  \
# 354143                          97                                    6
#
#        survey response rate percent survey response rate percent footnote  \
# ...

# %%
summary_star_rating_2024 = summary_star_rating_2024.rename(columns = {'county/parish': 'county name', 'city/town': 'city'}) 
#changed thecounty/parish column to county name and city/town column to cityto match all the others

# %%
summary_star_rating_2024
# Out:
#        facility id                                      facility name  \
# 354143      440001                            UNICOI COUNTY  HOSPITAL
# 354236      440002            JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 354329      440003  HIGHPOINT HEALTH-SUMNER WITH ASCENSION SAINT T...
# 354422      440006                     TRISTAR SKYLINE MEDICAL CENTER
# 354515      440007                               UNITY MEDICAL CENTER
# ...            ...                                                ...
# 362978      441320         WEST TENNESSEE HEALTHCARE BOLIVAR HOSPITAL
# 363071      441322                  HOUSTON COUNTY COMMUNITY HOSPITAL
# 363164      441323                      BIG SOUTH FORK MEDICAL CENTER
# 363257      443302                ST JUDE CHILDRENS RESEARCH HOSPITAL
# 363350      443303                  EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address        city state  zip code county name  \
# ...

# %%
summary_star_rating_all = pd.concat([summary_star_rating_2017, summary_star_rating_2018, summary_star_rating_2019, 
                                     summary_star_rating_2020, summary_star_rating_2021, summary_star_rating_2022, 
                                     summary_star_rating_2023, summary_star_rating_2024], axis=0)

# %%
summary_star_rating_all
# Out:
#        facility id                               facility name  \
# 191600      440001                     UNICOI COUNTY  HOSPITAL
# 191650      440002     JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 191700      440003              SUMNER REGIONAL MEDICAL CENTER
# 191750      440006              TRISTAR SKYLINE MEDICAL CENTER
# 191800      440007                        UNITY MEDICAL CENTER
# ...            ...                                         ...
# 362978      441320  WEST TENNESSEE HEALTHCARE BOLIVAR HOSPITAL
# 363071      441322           HOUSTON COUNTY COMMUNITY HOSPITAL
# 363164      441323               BIG SOUTH FORK MEDICAL CENTER
# 363257      443302         ST JUDE CHILDRENS RESEARCH HOSPITAL
# 363350      443303           EAST TENNESSEE CHILDRENS HOSPITAL
#
#                        address        city state  zip code county name  \
# 191600     100 GREENWAY CIRCLE       ERWIN    TN     37650      UNICOI
# ...

# %%
summary_star_rating_all['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3                301
# Not Available    236
# 4                169
# 2                 99
# 5                 23
# 1                  8
# Name: count, dtype: int64

# %%
summary_star_rating_all['patient survey star rating'].value_counts().plot(kind = 'barh');

# %%
summary_star_rating_all_clean = summary_star_rating_all.loc[summary_star_rating_all['patient survey star rating'] != 'Not Available']

# %%
summary_star_rating_all_clean.head(1)
# Out:
#        facility id                            facility name  \
# 191650      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
#
#                   address     city state  zip code county name  \
# 191650  620 SKYLINE DRIVE  JACKSON    TN     38301     MADISON
#
#        hcahps measure id      hcahps question hcahps answer description  \
# 191650     H_STAR_RATING  Summary star rating       Summary star rating
#
#        patient survey star rating patient survey star rating footnote  \
# 191650                          3                                 NaN
#
#        hcahps answer percent  hcahps answer percent footnote  \
# 191650        Not Applicable                             NaN
#
#        hcahps linear mean value number of completed surveys  \
# 191650           Not Applicable                        2170
#
#        number of completed surveys footnote survey response rate percent  \
# 191650                                  NaN                           23
#
# ...

# %%
summary_star_rating_all_clean['patient survey star rating'].value_counts()
# Out:
# patient survey star rating
# 3    301
# 4    169
# 2     99
# 5     23
# 1      8
# Name: count, dtype: int64

# %%
summary_star_rating_all_clean['patient survey star rating'].value_counts().plot(kind = 'barh');

# %%
summary_star_rating_all_clean['city_state'] = summary_star_rating_all_clean['city'] + ', ' + summary_star_rating_all_clean['state']
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\1171003194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary_star_rating_all_clean['city_state'] = summary_star_rating_all_clean['city'] + ', ' + summary_star_rating_all_clean['state']

# %%
summary_star_rating_all_clean.head(1)
# Out:
#        facility id                            facility name  \
# 191650      440002  JACKSON-MADISON COUNTY GENERAL HOSPITAL
#
#                   address     city state  zip code county name  \
# 191650  620 SKYLINE DRIVE  JACKSON    TN     38301     MADISON
#
#        hcahps measure id      hcahps question hcahps answer description  \
# 191650     H_STAR_RATING  Summary star rating       Summary star rating
#
#        patient survey star rating patient survey star rating footnote  \
# 191650                          3                                 NaN
#
#        hcahps answer percent  hcahps answer percent footnote  \
# 191650        Not Applicable                             NaN
#
#        hcahps linear mean value number of completed surveys  \
# 191650           Not Applicable                        2170
#
#        number of completed surveys footnote survey response rate percent  \
# 191650                                  NaN                           23
#
# ...

# %%
summary_star_rating_all_clean.loc[summary_star_rating_all_clean['year'] == 2023]
# Out:
#        facility id                                      facility name  \
# 356189      440002            JACKSON-MADISON COUNTY GENERAL HOSPITAL
# 356282      440003                     SUMNER REGIONAL MEDICAL CENTER
# 356375      440006                     TRISTAR SKYLINE MEDICAL CENTER
# 356468      440007                               UNITY MEDICAL CENTER
# 356561      440008                HENDERSON COUNTY COMMUNITY HOSPITAL
# ...            ...                                                ...
# 363443      440218           SAINT THOMAS HOSPITAL FOR SPINAL SURGERY
# 363536      440227                  TRISTAR STONECREST MEDICAL CENTER
# 363629      440228              SAINT FRANCIS BARTLETT MEDICAL CENTER
# 364373      441305                           MACON COMMUNITY HOSPITAL
# 364559      441307  HIGHPOINT HEALTH-RIVERVIEW WITH ASCENSION SAIN...
#
#                          address        city state  zip code county name  \
# ...

# %%
# Define a function to format the city_state field
def format_city_state(value):
    if ',' in value:
        city, state = value.split(',', 1)
        city = city.strip().title()        # Capitalize first letter of each word
        state = state.strip().upper()      # Ensure state is fully uppercase
        return f"{city}, {state}"
    return value

# Apply the function to the 'city_state' column
summary_star_rating_all_clean['city_state'] = summary_star_rating_all_clean['city_state'].apply(format_city_state)
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\281829502.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary_star_rating_all_clean['city_state'] = summary_star_rating_all_clean['city_state'].apply(format_city_state)

# %%
summary_star_rating_all_clean.city.unique()
# Out:
# array(['JACKSON', 'GALLATIN', 'NASHVILLE', 'MANCHESTER', 'CROSSVILLE',
#        'MARYVILLE', 'BRISTOL', 'KNOXVILLE', 'KINGSPORT', 'ELIZABETHTON',
#        'PULASKI', 'GREENEVILLE', 'FRANKLIN', 'MORRISTOWN', 'HARRIMAN',
#        'ROGERSVILLE', 'LA FOLLETTE', 'OAK RIDGE', 'CLARKSVILLE',
#        'DICKSON', 'MEMPHIS', 'MURFREESBORO', 'JEFFERSON CITY', 'TAZEWELL',
#        'WINCHESTER', 'COOKEVILLE', 'MARTIN', 'JOHNSON CITY',
#        'SPRINGFIELD', 'ATHENS', 'DYERSBURG', 'COLUMBIA', 'SEVIERVILLE',
#        'JAMESTOWN', 'SWEETWATER', 'CHATTANOOGA', 'FAYETTEVILLE',
#        'SAVANNAH', 'LENOIR CITY', 'UNION CITY', 'COVINGTON', 'PARIS',
#        'SHELBYVILLE', 'TULLAHOMA', 'SMITHVILLE', 'HERMITAGE',
#        'MC MINNVILLE', 'NEWPORT', 'LAWRENCEBURG', 'JELLICO', 'MC KENZIE',
#        'CLEVELAND', 'LIVINGSTON', 'SPARTA', 'LEBANON', 'HENDERSONVILLE',
#        'SMYRNA', 'BARTLETT', 'LAFAYETTE', 'CARTHAGE', 'DAYTON',
#        'MOUNTAIN HOME', 'POWELL', 'LEXINGTON', 'WAYNESBORO', 'HUNTINGDON',
# ...

# %%
summary_star_rating_all_clean.loc[summary_star_rating_all_clean['city'] == 'MOUNTAIN HOME']
# Out:
#        facility id                    facility name  \
# 245250      44016F  MOUNTAIN HOME VA MEDICAL CENTER
# 371348      44016F  MOUNTAIN HOME VA MEDICAL CENTER
# 370232      44016F  MOUNTAIN HOME VA MEDICAL CENTER
# 368093      44016F  MOUNTAIN HOME VA MEDICAL CENTER
# 367442      44016F  MOUNTAIN HOME VA MEDICAL CENTER
# 366047      44016F  MOUNTAIN HOME VA MEDICAL CENTER
# 362048      44016F  MOUNTAIN HOME VA MEDICAL CENTER
# 360002      44016F  MOUNTAIN HOME VA MEDICAL CENTER
#
#                                          address           city state  \
# 245250  CORNER OF LAMONT STREET AND VETERANS WAY  MOUNTAIN HOME    TN
# 371348  CORNER OF LAMONT STREET AND VETERANS WAY  MOUNTAIN HOME    TN
# 370232  CORNER OF LAMONT STREET AND VETERANS WAY  MOUNTAIN HOME    TN
# 368093  CORNER OF LAMONT STREET AND VETERANS WAY  MOUNTAIN HOME    TN
# 367442  CORNER OF LAMONT STREET AND VETERANS WAY  MOUNTAIN HOME    TN
# 366047  CORNER OF LAMONT STREET AND VETERANS WAY  MOUNTAIN HOME    TN
# ...

# %%
summary_star_rating_all_clean.to_csv('summary_star_rating_all_clean.csv', index = False)

# %%
summary_star_rating_all_clean.dtypes
# Out:
# facility id                               object
# facility name                             object
# address                                   object
# city                                      object
# state                                     object
# zip code                                   int64
# county name                               object
# hcahps measure id                         object
# hcahps question                           object
# hcahps answer description                 object
# patient survey star rating                object
# patient survey star rating footnote       object
# hcahps answer percent                     object
# hcahps answer percent footnote           float64
# hcahps linear mean value                  object
# number of completed surveys               object
# number of completed surveys footnote      object
# survey response rate percent              object
# survey response rate percent footnote     object
# ...

# %%
summary_star_rating_all_clean['patient survey star rating'] = pd.to_numeric(
    summary_star_rating_all_clean['patient survey star rating'])
# Out:
# C:\Users\barts\AppData\Local\Temp\ipykernel_24084\345594948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary_star_rating_all_clean['patient survey star rating'] = pd.to_numeric(

# %%
summary_star_rating_all_clean.dtypes
# Out:
# facility id                               object
# facility name                             object
# address                                   object
# city                                      object
# state                                     object
# zip code                                   int64
# county name                               object
# hcahps measure id                         object
# hcahps question                           object
# hcahps answer description                 object
# patient survey star rating                 int64
# patient survey star rating footnote       object
# hcahps answer percent                     object
# hcahps answer percent footnote           float64
# hcahps linear mean value                  object
# number of completed surveys               object
# number of completed surveys footnote      object
# survey response rate percent              object
# survey response rate percent footnote     object
# ...

# %%
summary_star_rating_all_clean_mean = summary_star_rating_all_clean.groupby('year')['patient survey star rating'].agg(['mean', 'count'])

# %%
summary_star_rating_all_clean_mean.reset_index(drop=False)
# Out:
#    year      mean  count
# 0  2017  3.250000     84
# 1  2018  3.209877     81
# 2  2019  3.077922     77
# 3  2020  2.967742     62
# 4  2021  3.108108     74
# 5  2022  3.223684     76
# 6  2023  3.216216     74
# 7  2024  3.236111     72

# %%
summary_star_rating_all_clean_mean.plot(kind='bar', y='mean')
plt.title("AVG STAR RATING PER YEAR")
plt.xlabel("YEAR")
plt.ylabel("avg rating")
plt.grid(True)
plt.show()
